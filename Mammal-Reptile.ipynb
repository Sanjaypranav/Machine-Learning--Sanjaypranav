# %% [markdown]
# Mamals and reptiles img

# %%
import pandas as pd
import numpy as np
from sklearn.tree import  DecisionTreeClassifier
import warnings
warnings. filterwarnings(action='ignore')
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# %%
data = pd.DataFrame({"toothed":["True","True","True","False","True","True","True","True","True","False"],
                     "hair":["True","True","False","True","True","True","False","False","True","False"],
                     "breathes":["True","True","True","True","True","True","False","True","True","True"],
                     "legs":["True","True","False","True","True","True","False","False","True","True"],
                     "species":["Mammal","Mammal","Reptile","Mammal","Mammal","Mammal","Reptile","Reptile","Mammal","Reptile"]}, 
                    columns=["toothed","hair","breathes","legs","species"])

features = data[["toothed","hair","breathes","legs"]]
target = data["species"]

# %%
data
# Out:
#   toothed   hair breathes   legs  species
# 0    True   True     True   True   Mammal
# 1    True   True     True   True   Mammal
# 2    True  False     True  False  Reptile
# 3   False   True     True   True   Mammal
# 4    True   True     True   True   Mammal
# 5    True   True     True   True   Mammal
# 6    True  False    False  False  Reptile
# 7    True  False     True  False  Reptile
# 8    True   True     True   True   Mammal
# 9   False  False     True   True  Reptile

# %%
pipe = Pipeline([('Label',OneHotEncoder()),('Dtr',DecisionTreeClassifier())],verbose = True)

# %%
pipe.fit(features,target)
# Out:
# [Pipeline] ............. (step 1 of 2) Processing Label, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing Dtr, total=   0.0s
# Pipeline(memory=None,
#          steps=[('Label',
#                  OneHotEncoder(categories='auto', drop=None,
#                                dtype=<class 'numpy.float64'>,
#                                handle_unknown='error', sparse=True)),
#                 ('Dtr',
#                  DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                         criterion='gini', max_depth=None,
#                                         max_features=None, max_leaf_nodes=None,
#                                         min_impurity_decrease=0.0,
#                                         min_impurity_split=None,
#                                         min_samples_leaf=1, min_samples_split=2,
#                                         min_weight_fraction_leaf=0.0,
# ...

# %%
pipe.predict([['True','False','True','False']])
# Out:
# array(['Reptile'], dtype=object)

# %%
import pickle
pickle.dump(pipe,open('mammal_model.pkl','wb'))

# %%
model = pickle.load(open('mammal_model.pkl','rb'))

# %%
model.predict([['True','False','True','False']])
# Out:
# array(['Reptile'], dtype=object)

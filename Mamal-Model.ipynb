# %%
import warnings
warnings. filterwarnings(action='ignore')
from sklearn.externals import joblib
import json
import numpy as np
from flask import request

# %%
model = joblib.load('/content/drive/MyDrive/Benkyou/ML WORKS/ML-for-Kids/Mammal_pipe.joblib')

# %%
model
